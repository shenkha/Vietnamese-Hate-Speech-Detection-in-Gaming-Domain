# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score,precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import seaborn as sn

# %%
# !git clone https://github.com/Honf03/CS114_Data_Final.git
# Out:
# fatal: destination path 'CS114_Data_Final' already exists and is not an empty directory.

# %%
train_data = pd.read_csv('/content/CS114_Data_Final/train.csv')
val_data = pd.read_csv('/content/CS114_Data_Final/val.csv')
test_data = pd.read_csv('/content/CS114_Data_Final/test.csv')

# %%
train_data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0   No.  \
# 0           259         259   260
# 1          1070        1070  1071
# 2          1531        1531  1532
# 3          1971        1971  1972
# 4          2210        2210  2211
#
#                                              Comment  Label
# 0                                    giàu vãi cả lồn      1
# 1                                                  g      0
# 2                                     rikaki hq buồn      0
# 3  hq thế_giới non lắm, sự_thật đi cháu, vô_địch ...      0
# 4                              khoa quánh veres t sợ      0

# %%
test_data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0   No.  \
# 0          6218        6218  6219
# 1          5935        5935  5936
# 2          5887        5887  5888
# 3          6898        6898  6899
# 4          1404        1404  1405
#
#                                              Comment  Label
# 0                                                 kệ      0
# 1  se mấy bữa_nay giả fan trung_lập đi nhục kinh lắm      2
# 2                                                NaN      0
# 3                                         thầy cổ_vũ      0
# 4                    bình_luận_viên hơi lạnh phải🤣🤣🤣      2

# %%
train_data.drop(train_data.columns[[0, 1, 2]], axis=1, inplace=True)
val_data.drop(val_data.columns[[0, 1, 2]], axis=1, inplace=True)
test_data.drop(test_data.columns[[0, 1, 2]], axis=1, inplace=True)

# %%
train_data['Comment'] = train_data['Comment'].astype(str)
val_data['Comment'] = val_data['Comment'].astype(str)
test_data['Comment'] = test_data['Comment'].astype(str)

# %%
train_data.head()
# Out:
#                                              Comment  Label
# 0                                    giàu vãi cả lồn      1
# 1                                                  g      0
# 2                                     rikaki hq buồn      0
# 3  hq thế_giới non lắm, sự_thật đi cháu, vô_địch ...      0
# 4                              khoa quánh veres t sợ      0

# %%
test_data.head()
# Out:
#                                              Comment  Label
# 0                                                 kệ      0
# 1  se mấy bữa_nay giả fan trung_lập đi nhục kinh lắm      2
# 2                                                nan      0
# 3                                         thầy cổ_vũ      0
# 4                    bình_luận_viên hơi lạnh phải🤣🤣🤣      2

# %%
X_train = train_data['Comment']
y_train = train_data['Label']
X_val = val_data['Comment']
y_val = val_data['Label']
X_test = test_data['Comment']
y_test = test_data['Label']

# %%
# Define the pipeline
pipeline = Pipeline([
    ('tfidf', TfidfVectorizer()),  # Feature extraction using TF-IDF
    ('classifier', RandomForestClassifier(n_estimators=108, max_depth = 400))  # Random Forest Classifier
])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('classifier',
#                  RandomForestClassifier(max_depth=400, n_estimators=108))])

# %%
y_pred = pipeline.predict(X_val)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_val, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95       608
#            1       0.84      0.78      0.81       147
#            2       0.62      0.24      0.35        54
#
#     accuracy                           0.90       809
#    macro avg       0.79      0.67      0.70       809
# weighted avg       0.89      0.90      0.89       809

# %%
y_pred = pipeline.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      1270
#            1       0.73      0.77      0.75       238
#            2       0.65      0.22      0.32       111
#
#     accuracy                           0.89      1619
#    macro avg       0.77      0.65      0.67      1619
# weighted avg       0.88      0.89      0.88      1619

# %%
cf1 = confusion_matrix(y_test, y_pred)
print(cf1)

evaluation = f1_score(y_test, y_pred, average='micro')

print("F1 - micro: " + str(evaluation))

evaluation = f1_score(y_test, y_pred, average='macro')
print("F1 - macro: " + str(evaluation))

evaluation = accuracy_score(y_test, y_pred)
print("Accuracy: " + str(evaluation))

df_cm1 = pd.DataFrame(cf1, index = ["clean","offensive","hate"],
                  columns = ["clean","offensive","hate"])
plt.clf()
sn.heatmap(df_cm1, annot=True, cmap="Greys",fmt='g', cbar=True, annot_kws={"size": 30})
# Out:
# [[1233   34    3]
#  [  44  184   10]
#  [  53   34   24]]
# F1 - micro: 0.8900555898702902
# F1 - macro: 0.674602090316376
# Accuracy: 0.8900555898702903
# <Axes: >

# %%
for i in range(len(y_pred)):
    if y_pred[i] != y_test[i]:
      print(test_data['Comment'][i], '|',y_pred[i] , '|', y_test[i])
# Out:
# se mấy bữa_nay giả fan trung_lập đi nhục kinh lắm | 0 | 2
# bình_luận_viên hơi lạnh phải🤣🤣🤣 | 0 | 2
# híu thảo đồ | 0 | 2
# who need dev 1 ve: v | 0 | 2
# mày đánh lux cặc | 1 | 2
# kéo | 1 | 0
# ??? huy bú | 1 | 2
# đặc cầu | 0 | 1
# aduvipwa | 0 | 1
# bé đần =]] | 1 | 2
# zeus non học 369:)))) | 0 | 2
# ys cặc | 1 | 2
# 2 đội gà v | 0 | 2
# bọn như cặc già | 1 | 0
# rên đi | 0 | 1
# nizy nhon vãi lồn =)) | 1 | 2
# mấy hề đánh | 0 | 2
# quang hải thịt trih trâu | 0 | 2
# cưỡi con_bé awesome | 0 | 2
# duma rừng | 0 | 1
# sài_gòn lạnh chúng_mày chẳng hiểu sao đá | 0 | 2
# red hút đá s | 0 | 2
# lồn out trình sea | 1 | 0
# ngu câm | 2 | 1
# moá đánh bắt | 0 | 1
# đù 18 | 1 | 0
# na hành máy quen =)) | 0 | 2
# diana điên | 1 | 2
# cứt | 2 | 1
# mẹ swap cứu nô_lệ | 1 | 0
# lê khánh vô_học | 0 | 2
# chấn bé đù | 1 | 2
# vcs rác | 0 | 2
# ngài điên | 1 | 2
# quốc nhục gân đàm | 0 | 1
# trụ rồng, chiến_thuật bọn gân đàm | 0 | 2
# mé tara ghê | 0 | 1
# ana ngáo đá | 0 | 2
# đùu | 0 | 1
# tật ác | 0 | 1
# thắng vua, thua se sủa | 1 | 2
# kênh chat toàn trẻ trâu chấp | 0 | 2
# dcm | 0 | 1
# đái quần | 1 | 0
# admin xong top 2 ngáo | 0 | 2
# xong mẹ game:))) | 1 | 0
# mẹ tưởng gọi | 1 | 0
# giọng thương vãi =))) | 1 | 0
# duyên_dáng đánh kém vãi lồn | 1 | 2
# vải:)) | 1 | 0
# địt_mẹ mày | 0 | 2
# kẹ mịa team đi ngài farm gánh | 0 | 1
# bá đần gánh team | 2 | 1
# cục bs ngon vãi | 1 | 0
# kênh chat bẩn | 0 | 2
# 2 subs bảo sấp mặt lờ | 0 | 1
# :)) bọn comment chiêu anet chửi red | 0 | 2
# nhục | 0 | 1
# clma pr | 0 | 1
# thay đầm đỏ lyly | 2 | 0
# neon vo hoc | 0 | 2
# pick ẻn zo đi bồn lình | 2 | 0
# giết gay | 2 | 1
# la viii | 1 | 0
# toàn bọn vô hăn hoá chat | 0 | 2
# đnáh dốt pha | 1 | 2
# chào coi condilon | 0 | 1
# khanhbeo an cut khanhbeo ancut | 0 | 2
# híu dễ_thương boà tr:)) | 0 | 2
# maky múa kinh vkl | 1 | 2
# g2 đánh cặc??? | 1 | 2
# dám pick medu, chả pick am vã mồm | 0 | 1
# mẹ bắt đi ngủ | 1 | 0
# mẹ sp s1 s2 | 1 | 0
# d hieu:)) | 0 | 1
# đéo bao h ulti rub sống | 1 | 0
# gáy hề 2 dỡ | 0 | 1
# lông | 0 | 1
# đổ vạ thằng mid địt bố mày | 0 | 2
# rank việt cao_thủ toàn gà, xoá gảm đi | 0 | 2
# ly da xấu nhở | 0 | 2
# mù mắt | 0 | 1
# dú dú dú anh em oi | 0 | 2
# cơ_bắp | 0 | 2
# view ff đéo 1 góc lq | 1 | 2
# ly lép anh em | 0 | 2
# giọng uống đá:)))) | 1 | 0
# dí cạc | 0 | 1
# g2 đần lắm, đừng | 1 | 2
# sp butter gà vãi cặc | 1 | 2
# đéo damg | 0 | 1
# mấy vcs ăn_mặc chán vãi lều | 1 | 2
# thắng làm gì. đi tê_liệt. | 1 | 0
# nauti kinred đù vãi cặc | 1 | 2
# ma vuong suyt như cặc ngoai` day | 1 | 0
# mana cút awesome | 0 | 1
# mấy đứa bảo fan blg chẳng_qua anti-fan geng, mấy gà, 3-0 geng | 0 | 2
# bố_láo | 0 | 1
# admin thằng ngáo | 0 | 2
# thua lane | 1 | 0
# blv lưỡi ngắn | 1 | 2
# lạ gáy | 0 | 1
# bênh xong ta t hảo cảm con_mẹ =. = " | 1 | 0
# game liên_quân trẻ trâu hiểu_biết. nhăn cuội, chả.:)) | 0 | 2
# mày sủa lắm bố mày súc_vật mày | 1 | 2
# duma top | 0 | 1
# vinhcs chán vãi lồn, lck lpl chuyên_môn, văn tùng phân_tích sâu =)) | 2 | 1
# d m quái_vật | 0 | 1
# con mẹ mày j4 | 1 | 2
# set ngài hơi phèn | 0 | 2
# cha_nội ngọng bl chả | 0 | 2
# ngu lắm | 2 | 1
# mong bá điền bl tụi anti haha | 0 | 2
# nhạc đb\ | 0 | 1
# d 'động vao no | 0 | 1
# rẻ_mạt | 0 | 1
# d m mày mid | 0 | 2
# mịa crazyguy_bảo | 0 | 1
# đéo | 1 | 0
# yado đánh_đấm quần què | 0 | 2
# hùng bú win hơi | 1 | 2
# deo bat untl | 0 | 1
# vô văn_hoá | 0 | 1
# tộc_người hang < (") | 1 | 0
# mid tao bảo may lồn | 1 | 2
# se lck đánh lồn view gam đánh rôi: v | 1 | 0
# lồn rừng | 1 | 2
# an cuc | 0 | 1
# lyly mặc bì al | 2 | 0
# lpl trung bán_độ máy_cày =)) | 0 | 2
# tró lày:)) | 0 | 2
# ngài điên mẹ | 1 | 2
# chương_trình truyền_hình mạng chửi thề tư_cách hả tùng | 0 | 2
# blg khéo vô_địch đội nhánh gam auto vô_địch, bùa lợi vcs vãi lồn | 1 | 2
# ngu học | 2 | 1
# mấy thánh sủa bậy | 1 | 0
# cú bu mèo đi híu | 0 | 2
# phế chết thay | 0 | 1
# ren đần sút | 1 | 2
# chán vãi lồn | 1 | 2
# trình gáy kinh lắm. thua đổ thừa vòng_vo bo, map tủ, quen meta.... cười ỉa. hứa. củ | 0 | 1
# mấy nhóc trẩu chê tuyển_thủ | 0 | 2
# lồn medusa hack tiền | 1 | 2
# moá sp lolz | 0 | 2
# kda rác vãi cặc | 1 | 2
# câm | 0 | 1
# cơm chó? | 1 | 0
# đá trứng cút hai blv đi híu | 0 | 2
# vlin mấy g2:)) | 0 | 2
# chiện vô_tri | 0 | 1
# bai tổn luồi | 0 | 2
# @ huy mai nhường??? đánh ngu xong kêu nhường, ba_mẹ dạy mày khiêm_tốn? ba_mẹ m chết | 0 | 2
# bú | 0 | 1
# bú | 0 | 1
# mẹ thả 3 | 1 | 0
# ngai` thi` cax nao hanh`:))) | 0 | 2
# mẹ mày | 2 | 1
# mid kỹ_năng, đi bú rừng | 1 | 2
# vng làm_ăn cặc | 1 | 2
# mẹ | 1 | 0
# vai biu kèo hồi xưa | 0 | 1
# vãi | 1 | 0
# rắn thành giun | 0 | 1
# mẹ | 1 | 0
# admin target xàm lồn | 2 | 1
# trình 36đái | 0 | 1
# t1ngu vãi cặc, pick nauti toàn thua pick tiếp | 1 | 2
# tướng xấu vãi cả lồn | 1 | 2
# mẹ đống mắt | 1 | 0
# m choi da | 0 | 2
# . gáy đi:))) | 0 | 1
# tlin đu | 1 | 0
# gánh ngu | 2 | 1
# mấy đoạn nhấn_nhá y_hệt giọng killjoy | 1 | 0
# 2 thằng blv đống rác liên_quân v?? | 0 | 2
# nguyên cỏ thằng trẻ_con học_đòi sơn lambo | 0 | 2
# lane | 1 | 0
# đậu đần vai tôn ngộ 7749 kiếp nạn gengu | 1 | 0
